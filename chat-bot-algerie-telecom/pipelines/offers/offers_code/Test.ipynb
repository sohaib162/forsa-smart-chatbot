# %%
from main_pipeline import Retriever

results = Retriever("Je suis abonné Idoom Fibre 120 Mbps, comment je peux activer l’offre WEEK-END BOOST pour le week-end ?", 3)
results
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 16 threads.
# INFO:pipeline.loader:Found 17 JSON files in D:\FORSA\Offer_Script\ARAB\individual_docs
# INFO:pipeline.loader:Successfully loaded 17 documents
# INFO:pipeline.pipeline:Building rule-based router (for filtering)...
# INFO:pipeline.rule_router:RuleRouter initialized with 17 documents (multilingual)
# INFO:pipeline.pipeline:Building sparse (BM25) index...
# INFO:pipeline.sparse_index:SparseIndex initialized with 17 documents, query_expansion=enabled (BM25 b=0.5)
# INFO:pipeline.pipeline:Retrieval pipeline initialized successfully (Sparse Fusion only).
# INFO:pipeline.pipeline:Processing query: Je suis abonné Idoom Fibre 120 Mbps, comment je peux activer l’offre WEEK-END BOOST pour le week-end...
# INFO:pipeline.pipeline:Stage 1: Rule-based filtering
# INFO:pipeline.rule_router:Rule filtering complete: returned 16 scored candidates (Top 15 kept)
# ...

# %%
import json

q = "internet pour gamers"
k = 3

results = Retriever(q, k)
for i, js in enumerate(results, 1):
    # Pretty-print first result fully, others truncated
    obj = json.loads(js)
    print(f"--- Doc #{i} id: {obj.get('document_id','N/A')} title_fr: {obj.get('metadata',{}).get('title_fr')}")
    print(json.dumps(obj, ensure_ascii=False, indent=2))
    print("\n")
# Out:
# INFO:pipeline.loader:Found 17 JSON files in D:\FORSA\Offer_Script\ARAB\individual_docs
# INFO:pipeline.loader:Successfully loaded 17 documents
# INFO:pipeline.pipeline:Building rule-based router (for filtering)...
# INFO:pipeline.rule_router:RuleRouter initialized with 17 documents (multilingual)
# INFO:pipeline.pipeline:Building sparse (BM25) index...
# INFO:pipeline.sparse_index:SparseIndex initialized with 17 documents, query_expansion=enabled (BM25 b=0.5)
# INFO:pipeline.pipeline:Retrieval pipeline initialized successfully (Sparse Fusion only).
# INFO:pipeline.pipeline:Processing query: internet pour gamers...
# INFO:pipeline.pipeline:Stage 1: Rule-based filtering
# INFO:pipeline.rule_router:Rule filtering complete: returned 2 scored candidates (Top 15 kept)
# INFO:pipeline.pipeline:Stage 2: Sparse Fusion for Final Ranking (Candidate Pool Size: 6)
# INFO:pipeline.sparse_index:Sparse Fused Search: Found 2 results, top score: 1.0000
# ...

# %%
from Retriever import Retriever

results = Retriever("internet pour gamers", 3)
print(results)
# Out:
# INFO:pipeline.loader:Found 17 JSON files in D:\FORSA\Offer_Script\ARAB\individual_docs
# INFO:pipeline.loader:Successfully loaded 17 documents
# INFO:pipeline.pipeline:Building rule-based router (for filtering)...
# INFO:pipeline.rule_router:RuleRouter initialized with 17 documents (multilingual)
# INFO:pipeline.pipeline:Building sparse (BM25) index...
# INFO:pipeline.sparse_index:SparseIndex initialized with 17 documents, query_expansion=enabled (BM25 b=0.5)
# INFO:pipeline.pipeline:Retrieval pipeline initialized successfully (Sparse Fusion only).
# INFO:pipeline.pipeline:Processing query: internet pour gamers...
# INFO:pipeline.pipeline:Stage 1: Rule-based filtering
# INFO:pipeline.rule_router:Rule filtering complete: returned 2 scored candidates (Top 15 kept)
# INFO:pipeline.pipeline:Stage 2: Sparse Fusion for Final Ranking (Candidate Pool Size: 6)
# INFO:pipeline.sparse_index:Sparse Fused Search: Found 2 results, top score: 1.0000
# ...
